# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Model Evaluation & Validation
# ## Project 1: Predicting Boston Housing Prices
#
# Welcome to the first project of the Machine Learning Engineer Nanodegree! In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'Implementation'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ## Getting Started
# In this project, you will evaluate the performance and predictive power of a model that has been trained and tested on data collected from homes in suburbs of Boston, Massachusetts. A model trained on this data that is seen as a *good fit* could then be used to make certain predictions about a home — in particular, its monetary value. This model would prove to be invaluable for someone like a real estate agent who could make use of such information on a daily basis.
#
# The dataset for this project originates from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Housing). The Boston housing data was collected in 1978 and each of the 506 entries represent aggregated data about 14 features for homes from various suburbs in Boston, Massachusetts. For the purposes of this project, the following preprocessing steps have been made to the dataset:
# - 16 data points have an `'MEDV'` value of 50.0. These data points likely contain **missing or censored values** and have been removed.
# - 1 data point has an `'RM'` value of 8.78. This data point can be considered an **outlier** and has been removed.
# - The features `'RM'`, `'LSTAT'`, `'PTRATIO'`, and `'MEDV'` are essential. The remaining **non-relevant features** have been excluded.
# - The feature `'MEDV'` has been **multiplicatively scaled** to account for 35 years of market inflation.
#
# Run the code cell below to load the Boston housing dataset, along with a few of the necessary Python libraries required for this project. You will know the dataset loaded successfully if the size of the dataset is reported.

# %%
# Import libraries necessary for this project
import numpy as np

import pandas as pd

import visuals as vs # Supplementary code

from sklearn import cross_validation

from sklearn.cross_validation import ShuffleSplit

from sklearn import svm

from IPython.display import Image

# Pretty display for notebooks
# %matplotlib inline

# Load the Boston housing dataset
data = pd.read_csv('housing.csv')
prices = data['MEDV']
features = data.drop('MEDV', axis = 1)
    
# Success
print "Boston housing dataset has {} data points with {} variables each.".format(*data.shape)
# Out:
# Boston housing dataset has 489 data points with 4 variables each.

# %% [markdown]
# ## Data Exploration
# In this first section of this project, you will make a cursory investigation about the Boston housing data and provide your observations. Familiarizing yourself with the data through an explorative process is a fundamental practice to help you better understand and justify your results.
#
# Since the main goal of this project is to construct a working model which has the capability of predicting the value of houses, we will need to separate the dataset into **features** and the **target variable**. The **features**, `'RM'`, `'LSTAT'`, and `'PTRATIO'`, give us quantitative information about each data point. The **target variable**, `'MEDV'`, will be the variable we seek to predict. These are stored in `features` and `prices`, respectively.

# %% [markdown]
# ### Implementation: Calculate Statistics
# For your very first coding implementation, you will calculate descriptive statistics about the Boston housing prices. Since `numpy` has already been imported for you, use this library to perform the necessary calculations. These statistics will be extremely important later on to analyze various prediction results from the constructed model.
#
# In the code cell below, you will need to implement the following:
# - Calculate the minimum, maximum, mean, median, and standard deviation of `'MEDV'`, which is stored in `prices`.
#   - Store each calculation in their respective variable.

# %%
# TODO: Minimum price of the data
minimum_price = np.min(prices)

# TODO: Maximum price of the data
maximum_price = np.max(prices)

# TODO: Mean price of the data
mean_price = np.mean(prices)

# TODO: Median price of the data
median_price = np.median(prices)

# TODO: Standard deviation of prices of the data
std_price = np.std(prices)

# Show the calculated statistics
print "Statistics for Boston housing dataset:\n"
print "Minimum price: ${:,.2f}".format(minimum_price)
print "Maximum price: ${:,.2f}".format(maximum_price)
print "Mean price: ${:,.2f}".format(mean_price)
print "Median price ${:,.2f}".format(median_price)
print "Standard deviation of prices: ${:,.2f}".format(std_price)
# Out:
# Statistics for Boston housing dataset:
#
# Minimum price: $105,000.00
# Maximum price: $1,024,800.00
# Mean price: $454,342.94
# Median price $438,900.00
# Standard deviation of prices: $165,171.13

# %% [markdown]
# ### Question 1 - Feature Observation
# As a reminder, we are using three features from the Boston housing dataset: `'RM'`, `'LSTAT'`, and `'PTRATIO'`. For each data point (neighborhood):
# - `'RM'` is the average number of rooms among homes in the neighborhood.
# - `'LSTAT'` is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - `'PTRATIO'` is the ratio of students to teachers in primary and secondary schools in the neighborhood.
#
# _Using your intuition, for each of the three features above, do you think that an increase in the value of that feature would lead to an **increase** in the value of `'MEDV'` or a **decrease** in the value of `'MEDV'`? Justify your answer for each._
# **Hint:** Would you expect a home that has an `'RM'` value of 6 be worth more or less than a home that has an `'RM'` value of 7?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 5))

count = 1
color = [0,'r','b','g']

for col in (features.columns):
    
    plt.subplot(1, 3, count)
    
    plt.plot(data[col], prices, 'o', color = color[count])
    
    plt.title(col)
    
    plt.xlabel(col)
    
    plt.ylabel('prices')
    
    count += 1

# %% [markdown]
# #### Answer:
#
# #### 1) RM (Average number of rooms among homes in the neighbourhood):
# - Increase in the average number of rooms among homes in the neighbourhood will increase the value of the houseing price "MEDV" since it will most likely denote to more square footage of the house. As the area of the house increase, cost and the worth will also increase.
#
# - The houses are also evaluated for price on the square footage.
#
# - More rooms also may denote to more comfortable accomodation of the residents of the house, hence an increase in value of the house "MEDV".
#
# #### 2) LSTAT (percentage of homeowners in the neighbourhood considered "lower class" (working poor)):
#
# - With the increase in LSTAT we will most likely notice a reduction/decrease in "MEDV"
# - The lower class can be infered to a a family earning lower paying jobs. In most cases, this may also infer to less educational background and hence unable to find a higher paying technical job.
#
# - With an increase in LSTAT, since I am assuming the family to be lacking in higher educaton may also infer in adverse effects on the psychological environment due to formal educational refinement. Hence this may lead to a decrease in house prices MEDV since the area will not be considered as friendly or a safe healthy enviroment of more educated familes who are earning income in higher brackets.
#
# #### 3) PTRATIO (Student - Teacher Ratio in the primary and secondary schools in the neighbourhood):
# - With an increase in Student to Teacher ratio , we can assume and infer a decrease in MEDV
# - Higher student to teacher ratio leads to less individual attention to the students, which results in poorer acamedic and overall character results.
# - Increase in PTRATIO infers teachers have more work to tackle, leaving them with no to less room for focusing on imporving grades and character of the individual students.
# ...

# %% [markdown]
# ----
#
# ## Developing a Model
# In this second section of the project, you will develop the tools and techniques necessary for a model to make a prediction. Being able to make accurate evaluations of each model's performance through the use of these tools and techniques helps to greatly reinforce the confidence in your predictions.

# %% [markdown]
# ### Implementation: Define a Performance Metric
# It is difficult to measure the quality of a given model without quantifying its performance over training and testing. This is typically done using some type of performance metric, whether it is through calculating some type of error, the goodness of fit, or some other useful measurement. For this project, you will be calculating the [*coefficient of determination*](http://stattrek.com/statistics/dictionary.aspx?definition=coefficient_of_determination), R<sup>2</sup>, to quantify your model's performance. The coefficient of determination for a model is a useful statistic in regression analysis, as it often describes how "good" that model is at making predictions.
#
# The values for R<sup>2</sup> range from 0 to 1, which captures the percentage of squared correlation between the predicted and actual values of the **target variable**. A model with an R<sup>2</sup> of 0 always fails to predict the target variable, whereas a model with an R<sup>2</sup> of 1 perfectly predicts the target variable. Any value between 0 and 1 indicates what percentage of the target variable, using this model, can be explained by the **features**. *A model can be given a negative R<sup>2</sup> as well, which indicates that the model is no better than one that naively predicts the mean of the target variable.*
#
# For the `performance_metric` function in the code cell below, you will need to implement the following:
# - Use `r2_score` from `sklearn.metrics` to perform a performance calculation between `y_true` and `y_predict`.
# - Assign the performance score to the `score` variable.

# %%
# TODO: Import 'r2_score'

from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    
    # TODO: Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true= y_true, y_pred= y_predict)
    
    # Return the score
    return score

# %% [markdown]
# ### Question 2 - Goodness of Fit
# Assume that a dataset contains five data points and a model made the following predictions for the target variable:
#
# | True Value | Prediction |
# | :-------------: | :--------: |
# | 3.0 | 2.5 |
# | -0.5 | 0.0 |
# | 2.0 | 2.1 |
# | 7.0 | 7.8 |
# | 4.2 | 5.3 |
# *Would you consider this model to have successfully captured the variation of the target variable? Why or why not?*
#
# Run the code cell below to use the `performance_metric` function and calculate this model's coefficient of determination.

# %%
# Calculate the performance of this model
score = performance_metric([3, -0.5, 2, 7, 4.2], [2.5, 0.0, 2.1, 7.8, 5.3])
print "Model has a coefficient of determination, R^2, of {:.3f}.".format(score)
# Out:
# Model has a coefficient of determination, R^2, of 0.923.

# %% [markdown]
# #### Answer:
#
# #### R^2 - Coeffienent of Determination:
# - The R^2 or Coefficient of determination evaluates how good the regression and it describes what part of the regression does not contain errors.
#
# - the optimal value of R^2/ Coefficient of Determination is 1 (100%) which means the test curve was perfected predicted from the triaing data.
#
# - Since R^2 is 92.3%, it denotes there is only 7.7% error.
#
# - Although, after evaluating the model, and looking at the training and testing splits for performance errors: bias and variances through learning curve, we may improve the results even more.
#
# - Apart from R^2 , we can evaluate Mean Suquared Error (MAE) and Mean Absolute Error (MAE)

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Your next implementation requires that you take the Boston housing dataset and split the data into training and testing subsets. Typically, the data is also shuffled into a random order when creating the training and testing subsets to remove any bias in the ordering of the dataset.
#
# For the code cell below, you will need to implement the following:
# - Use `train_test_split` from `sklearn.cross_validation` to shuffle and split the `features` and `prices` data into training and testing sets.
#   - Split the data into 80% training and 20% testing.
#   - Set the `random_state` for `train_test_split` to a value of your choice. This ensures results are consistent.
# - Assign the train and testing splits to `X_train`, `X_test`, `y_train`, and `y_test`.

# %%
# TODO: Import 'train_test_split'

from sklearn import cross_validation

# TODO: Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = cross_validation.train_test_split(features,prices, train_size= 0.8,test_size= 0.2, random_state= 0)


# Success
print "Training and testing split was successful."
# Out:
# Training and testing split was successful.

# %% [markdown]
# ### Question 3 - Training and Testing
# *What is the benefit to splitting a dataset into some ratio of training and testing subsets for a learning algorithm?*
# **Hint:** What could go wrong with not having a way to test your model?

# %% [markdown]
# ##### Answer:
#
# ##### Splitting Dataset into Train and Test Sets
#
# - When we split the data into train and test sets.
#
# - We create a model to compare our prediction on solid grounds, the predictions are measurable
#
# - We can analyzie the performance of the prediction model since the same data is split into training data and test data.
#
# - If the R^2 is high like in this case 92%, we can infer that there will be more accuracy while computing recall and precision.
#
# - We can further use K-fold methods to test our model K number of times where the data set is divided into buckets, with each fold the buckets can be swaped for train and test data.

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# In this third section of the project, you'll take a look at several models' learning and testing performances on various subsets of training data. Additionally, you'll investigate one particular algorithm with an increasing `'max_depth'` parameter on the full training set to observe how model complexity affects performance. Graphing your model's performance based on varying criteria can be beneficial in the analysis process, such as visualizing behavior that may not have been apparent from the results alone.

# %% [markdown]
# ### Learning Curves
# The following code cell produces four graphs for a decision tree model with different maximum depths. Each graph visualizes the learning curves of the model for both training and testing as the size of the training set is increased. Note that the shaded region of a learning curve denotes the uncertainty of that curve (measured as the standard deviation). The model is scored on both the training and testing sets using R<sup>2</sup>, the coefficient of determination.
#
# Run the code cell below and use these graphs to answer the following question.

# %%
# Produce learning curves for varying training set sizes and maximum depths
vs.ModelLearning(features, prices)

# %% [markdown]
# ### Question 4 - Learning the Data
# *Choose one of the graphs above and state the maximum depth for the model. What happens to the score of the training curve as more training points are added? What about the testing curve? Would having more training points benefit the model?*
# **Hint:** Are the learning curves converging to particular scores?

# %% [markdown]
# #### Answer:
#
# #### Plot - With Max Depth = 3 :
#
# - With the increase in training points the training curve reduces in accuracy/performance.
#
# - This is due to the reason as more points are added to the training curve, there is a increase in diversity in the data set increasing the matrix for computing precision and recall. Never-the-less, with additional training points reaching to a population of 300, the system of prediction for training curve stablizes to an accuracy of 80%.
#
# - With the increase in training points testing curves improves in predicition performance and eventually the performance stablizes/plateaus at 300 points.
#
# - As testing points are added to the testing curve, score improves.
#
# - This is due to the reason we have more data to train the model, at a healthly level of dimensions around 3-4 along with enough training data the model becomes capable to analyze the general trend for the prediciton.
#
# - By adding arounf 300 training points R^2, coefficient of determination, training & testing curves plateaus to an accuracy of around 80% (with 20% error).
#
# - The training and training curves benifited from adding more training points from 50 to 300, then less signs of accuracy imporovements where evident in the model.
#
# - The training and testing curves converge also around the same amount of data points, 300.
#
# - The Learning Curve is Ideal, since there is no bias (train & test curve intersection likeplot plot with max depth of 1), high variance (train & test curve far apart like in max depth of 6 and 10), and R^2 score is high 80% which denotes 80% of the prediction does not describe errors (80 % error free prediction).

# %% [markdown]
# ### Complexity Curves
# The following code cell produces a graph for a decision tree model that has been trained and validated on the training data using different maximum depths. The graph produces two complexity curves — one for training and one for validation. Similar to the **learning curves**, the shaded regions of both the complexity curves denote the uncertainty in those curves, and the model is scored on both the training and validation sets using the `performance_metric` function.
#
# Run the code cell below and use this graph to answer the following two questions.

# %%
vs.ModelComplexity(X_train, y_train)

# %% [markdown]
# ### Question 5 - Bias-Variance Tradeoff
# *When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10? What visual cues in the graph justify your conclusions?*
# **Hint:** How do you know when a model is suffering from high bias or high variance?

# %% [markdown]
# !["Visualization of Bias and Variance by a Regressoin Forecast"](biasvariance_old.jpg)
#
# #### Answer:
#
# #### Model Trained with a Max Depth of 1:
# - This model sufferes from high bias as training curve is intersecting uncertainty area of the test curve/ Validatoin (area with testing curve standard deviation).
# - At the maximum depth of 1 of the desicion tree, from 50 training points onwards:
# -- The training and testing curves are so close that thier area of standard deviation is intersecting all along from 50 points onwards.
# -- Both the curves are getting closer to eachother as training points increase in population.
# -- The training curve is declining in accuracy from 56% to 40% in accuracy, by the time we are training using 300+ points.
# -- The testining curve performance does not improve given a single dimension from any where starting from 50 points of training data onwards.
#
#
# #### Model Trained with a Max Depth of 10:
# - This model sufferes from high variance as the training curve is far apart from test curve which denotes the testing results are not able to generalize the prediction model.
# - This is leading to a lowest score in the performace when model is trained at max depth of 10 of the decision tree.

# %% [markdown]
# ### Question 6 - Best-Guess Optimal Model
# *Which maximum depth do you think results in a model that best generalizes to unseen data? What intuition lead you to this answer?*

# %% [markdown]
# #### Answer:
#
# #### Model that best generalizes to unseen data: (Max Depth = 3)
#
# - The model with maximum depth of 3, the training and the testing curves are converging very closely.
#
# - The coefficient of determination, R^2, is highiest at 80%, which denotes the model is 80% accurately predicting the training data.
#
# - The learning curve performance at max depth of 3 is around 80% for the decision trees prediction .
#
# - Any higher depths is showing signs of increase variance and reduction in learning performance score of the decision tree prediction,
#
# - And any lower depth than 3 is showing signs of high bias due to intersection and a lower performance score of the decision tree prediction.
#
# - Although another important aspect will be the validation score.
#
# - The complexity performance at the depth 4 of the decision tree also has a very good balance of variance and bias along with the highest validation score around 85%.
#
# - The max_depth of 3 model over  max_depth of 4 model meets Occam's Razor Theroy.
#
# !['Looking for the highest Validation Score'](biasvariance.png)

# %% [markdown]
# -----
#
# ## Evaluating Model Performance
# In this final section of the project, you will construct a model and make a prediction on the client's feature set using an optimized model from `fit_model`.

# %% [markdown]
# ### Question 7 - Grid Search
# *What is the grid search technique and how it can be applied to optimize a learning algorithm?*

# %% [markdown]
# #### Answer:
#
# #### Search Grid:
#
# - A search grid estimates the best estimator sub parameters for prediction function parameters such as SVM, which it is not learning by default in the function.
#
# - Examples of such estimator parameters are :
# -- SVM : C, Gamma, Kernal
# -- Lasso: alpha
#
# - These can be learning using cross validation : evaluating estimator performance.
#
# - A range of these sub-parameters are provided, and grid search can perform an exhaustive or random process to apply these sub parameters and output the best choice for the prediction model.
#
# - The exhaustive GridSearch can be very computationally expensive (O^n) since it has apply very combination of the hyper-paramters.
#
# - This is evident when there are large matrices of hyper-paramters and it has to apply recursively through a large data set.
#
# ##### We can reduce the Time complexity of the GridSearch algorithm by using:
#
# -- RandomizedSearchCV: it samples restricted amounts of candidates from a parameter space with a specified distribution. This methods provides efficient results!
#
# -- Train/ Validation/ Test Split: we can validate our model on the validation set, which is often used with much bigger data-sets.
#
# ##### The search grid consist of these following requirements:
# - Parameter: These can be regressor or classifier functions such as SVM, Linear Regression
# - Parameter Space
# - Method of searcyhing or sampling
# - Crossvalidation scheme
# - score function

# %% [markdown]
# ### Question 8 - Cross-Validation
# *What is the k-fold cross-validation training technique? What benefit does this technique provide for grid search when optimizing a model?*
# **Hint:** Much like the reasoning behind having a testing set, what could go wrong with using grid search without a cross-validated set?

# %% [markdown]
# #### Answer:
#
# #### K-fold Cross Validation, and benifits for Grid Search:
#
# ##### K-fold cross-validation training technique:
# - In this technique we split the data into equal bins, and use some data for training and some for testing.
# - Then we rerun the bins with a different combination of training and testing bin sets.
# - We run the cross-validation K number of times.
#
# ##### Details of K-fold CrossValidation:
# - The default number for k is 10, but it can be increased of decreased.
# - Lets suppose we are performing a 10-fold cross validation.
# - The total population will be equally divided in 10 equal sub-sets.
# - These 10 bins of data will be split in a holdout of training and testing set ratio of (k-1):1
# - On the first fold, the 1st bin will be used as the testing set and rest of the 9 bins of data will be used for training the model.
# - On the second fold , the 2nd bin will only be used for testing data and the rest of the 9 bins will be used as training set.
# - There will be total of 10 folds, with each fold only 1 bin will be a learner and 9 bins will be training data.
# - At the end of the 10th cross-validation the scores of each fold will be averaged to compute an overall mean performance score of the test error.)
# - The variance of the result is reduced (which is usually higer in cv) by increasing the number of k.
# - With more number of bins, the chances of generaliztion of the model increase as there is always a larger portion of training set than the learner bin with higher amounts of k.
# - One disadvantage of this method of k-folds using k-1:1 ratio is bigger time complexity.
# - The Asymptotic time complexity of k-fold cross-validation k-1:1 is atleast O^k, which can be costly for large data bin iterations.
# - A Varient of it is to randomly divide the data into test and training set k different times.
# - the advantage of this  method is you can choose the size of the split and the number of trials you average over.
# !["K-folds CrossValidation"](kfoldcv.png)
#
#
# ##### Benifits of using Grid Search with K-fold Cross-Validation:
#
# - When we apply Grid-Search to k-fold cross-validation training technique, we are tuning the hyper-paramters everytime we run a new fold and we choose k-1 bins for training and one for testing.
# - Grid-Search helps tune the training and testing sets to the best sub-parameter setting resulting in least amount of bias and variances introduced in the prediction model.
# - K-fold cross-validation with GridSearch helps us identify the best choice for the hyper-paramters required to reduce margin of error and coefficient of determination, R^2 from the prediction curve.
#
# - This method enables to us to get better estimates of the voltality of the model by giving the overal mean of the error rate, thus it is represents a comprehensive generalization error.

# %%
from sklearn import tree

# build a Linear Regression model for predicting boston housing.

#clf = svm.SVC(kernel= 'linear', C=1, probability= True).fit(X_train,y_train)

#clf = linear_model.LinearRegression().fit(X_train,y_train)

clf = tree.DecisionTreeRegressor(max_depth=4, random_state=0)

# measuring its performance with a single test sub-set

#print clf.predict(X_test,y_test)

# we give cross validation model to the entire data set and its real values, and number of folds

scores = cross_validation.cross_val_score(clf,features,prices, cv = 18)

# print accuracy for each fold
print scores

# mean accuracy of all 10 folds

#scores =  np.abs(scores)

print type(scores)

print "\n mean score \n"

print np.mean(scores)

plt.figure(figsize=(20, 5))

plt.plot(scores)

plt.title("Decision Tree Regressor K-fold CV Score")
    
plt.xlabel("K-Folds")
    
plt.ylabel('Coefficient of Determination Score, R^2')

score_list = list()
for score in scores:
    if score >= 0:
        score_list.append(score)
        
print "\n R^2 k-fold cv score after correction \n"
        
print score_list

print "\n mean score after correction \n"

print np.mean(score_list)

plt.figure(figsize=(20, 5))

plt.plot(score_list)

plt.title("Decision Tree Regressor K-fold CV Score after correction")
    
plt.xlabel("K-Folds")
    
plt.ylabel('Coefficient of Determination Score, R^2')
# Out:
# [ 0.68716148  0.7894008   0.81352021  0.74316944  0.0770923   0.51001232
#   0.31488094  0.66844365  0.85803916  0.58014141  0.62056316  0.15657363
#   0.36623965  0.02296086  0.28343139 -0.77269877  0.14489825  0.28198075]
# <type 'numpy.ndarray'>
#
#  mean score
#
# 0.396989479384
#
#  R^2 k-fold cv score after correction
#
# [0.68716148477451255, 0.78940079923919104, 0.8135202101882939, 0.74316943538287961, 0.077092300417048065, 0.51001232036280864, 0.31488094283452428, 0.66844365454109766, 0.8580391562366243, 0.58014140866182429, 0.62056316243366405, 0.15657362813083986, 0.36623964842759577, 0.022960857819897429, 0.2834313854469116, 0.14489824826907283, 0.28198075133750339]
#
#  mean score after correction
#
# 0.465794670265

# %% [markdown]
# ### Implementation: Fitting a Model
# Your final implementation requires that you bring everything together and train a model using the **decision tree algorithm**. To ensure that you are producing an optimized model, you will train the model using the grid search technique to optimize the `'max_depth'` parameter for the decision tree. The `'max_depth'` parameter can be thought of as how many questions the decision tree algorithm is allowed to ask about the data before making a prediction. Decision trees are part of a class of algorithms called *supervised learning algorithms*.
#
# For the `fit_model` function in the code cell below, you will need to implement the following:
# - Use [`DecisionTreeRegressor`](http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html) from `sklearn.tree` to create a decision tree regressor object.
#   - Assign this object to the `'regressor'` variable.
# - Create a dictionary for `'max_depth'` with the values from 1 to 10, and assign this to the `'params'` variable.
# - Use [`make_scorer`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html) from `sklearn.metrics` to create a scoring function object.
#   - Pass the `performance_metric` function as a parameter to the object.
#   - Assign this scoring function to the `'scoring_fnc'` variable.
# - Use [`GridSearchCV`](http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.GridSearchCV.html) from `sklearn.grid_search` to create a grid search object.
#   - Pass the variables `'regressor'`, `'params'`, `'scoring_fnc'`, and `'cv_sets'` as parameters to the object.
#   - Assign the `GridSearchCV` object to the `'grid'` variable.

# %%
# TODO: Import 'make_scorer', 'DecisionTreeRegressor', and 'GridSearchCV'

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer
from sklearn.grid_search import GridSearchCV


def fit_model(X, y):
    """ Performs grid search over the 'max_depth' parameter for a 
        decision tree regressor trained on the input data [X, y]. """
    
    # Create cross-validation sets from the training data
    cv_sets = ShuffleSplit(X.shape[0], n_iter = 10, test_size = 0.20, random_state = 0)

    # TODO: Create a decision tree regressor object
    regressor = DecisionTreeRegressor(random_state= 0)

    # TODO: Create a dictionary for the parameter 'max_depth' with a range from 1 to 10
    params = { 'max_depth' : list(range(1,11)) }
    # TODO: Transform 'performance_metric' into a scoring function using 'make_scorer' 
    scoring_fnc = make_scorer(performance_metric)

    # TODO: Create the grid search object
    grid = GridSearchCV(estimator= regressor, param_grid= params, scoring= scoring_fnc, cv= cv_sets)

    # Fit the grid search object to the data to compute the optimal model
    grid = grid.fit(X, y)

    # Return the optimal model after fitting the data
    return grid.best_estimator_

# %% [markdown]
# ### Making Predictions
# Once a model has been trained on a given set of data, it can now be used to make predictions on new sets of input data. In the case of a *decision tree regressor*, the model has learned *what the best questions to ask about the input data are*, and can respond with a prediction for the **target variable**. You can use these predictions to gain information about data where the value of the target variable is unknown — such as data the model was not trained on.

# %% [markdown]
# ### Question 9 - Optimal Model
# _What maximum depth does the optimal model have? How does this result compare to your guess in **Question 6**?_
#
# Run the code block below to fit the decision tree regressor to the training data and produce an optimal model.

# %%
# Fit the training data to the model using grid search


reg = fit_model(X_train, y_train)

# Produce the value for 'max_depth'
print "Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth'])
# Out:
# Parameter 'max_depth' is 4 for the optimal model.

# %% [markdown]
# #### Answer:
#
# ##### Maximum depth of 4 dimensions is optimal for the prediction model.
# - The first estimation in question 6 was at the max depth of 3 of the decision tree.
# - The optimal model is one depth above my last choice.
# - The model at max_depth of 4 has a better performance score/highest validation score than model at the max_depth of 3,
#
# - Higher variance for the model with max_depth 4 is a trade off for better performance score, I will explore both max_depth 3 and 4 in more detail before implementing it for prediction.

# %% [markdown]
# ### Question 10 - Predicting Selling Prices
# Imagine that you were a real estate agent in the Boston area looking to use this model to help price homes owned by your clients that they wish to sell. You have collected the following information from three of your clients:
#
# | Feature | Client 1 | Client 2 | Client 3 |
# | :---: | :---: | :---: | :---: |
# | Total number of rooms in home | 5 rooms | 4 rooms | 8 rooms |
# | Neighborhood poverty level (as %) | 17% | 32% | 3% |
# | Student-teacher ratio of nearby schools | 15-to-1 | 22-to-1 | 12-to-1 |
# *What price would you recommend each client sell his/her home at? Do these prices seem reasonable given the values for the respective features?*
# **Hint:** Use the statistics you calculated in the **Data Exploration** section to help justify your response.
#
# Run the code block below to have your optimized model make predictions for each client's home.

# %%
# Produce a matrix for client data
client_data = [[5, 17, 15], # Client 1
               [4, 32, 22], # Client 2
               [8, 3, 12]]  # Client 3

# Show predictions
for i, price in enumerate(reg.predict(client_data)):
    print "Predicted selling price for Client {}'s home: ${:,.2f}".format(i+1, price)
# Out:
# Predicted selling price for Client 1's home: $391,183.33
# Predicted selling price for Client 2's home: $189,123.53
# Predicted selling price for Client 3's home: $942,666.67

# %% [markdown]
# #### Answer:
#
# ###### Statistics for Boston housing dataset:
#
# - 'Minimum price: $ 105,000'
# - 'Maximum price: $1,024,800'
# - 'Mean price: $454,342'
# - 'Median price $438,900'
# - 'Standard deviation of prices: $165,171'
#
# - Client 1 has 5 rooms, 17% poverity in the neighbourhood, 15:1 student teacher ratio:
# -- Predicted price of the house is $391,183 , this is $60,000 lower than the mean.
# -- Without further exploring the data, I will assume this is a vaild estimation since it lyes within the std deviation, but not the best.
# -- I will recommend the client to start by selling at the mean price
# -- Since number of rooms are good , poverity level is good, student teacher ratio is very good (any thing below 17:1 is considered good).
#
# - Client 2 has 4 rooms, 32% poverity in the neighbourhood, 22:1 student teacher ratio:
# -- Predicted price of the house is $189,123, it is below the std deviation but above the minium price.
# -- The number of rooms are good, poverity level is poor, and schools have a very poor student to teacher ratio of 22:1 (17:1 is recommended).
# -- I will have to explore the offset houses around the neighbour for prices before recommending my self, hence I will give the predicted price.
#
# - Client 3 has 8 rooms, 3% poverity level in the neighbourhood, 12:1 student teacher ratio:
# -- Predicted price for the house is $942,123, this is towards the higher side of the prices specturm.
# -- The number of rooms are excellent, poverity level is excellent, student to teacher ratio is excellent

# %% [markdown]
# ### Sensitivity
# An optimal model is not necessarily a robust model. Sometimes, a model is either too complex or too simple to sufficiently generalize to new data. Sometimes, a model could use a learning algorithm that is not appropriate for the structure of the data given. Other times, the data itself could be too noisy or contain too few samples to allow a model to adequately capture the target variable — i.e., the model is underfitted. Run the code cell below to run the `fit_model` function ten times with different training and testing sets to see how the prediction for a specific client changes with the data it's trained on.

# %%
vs.PredictTrials(features, prices, fit_model, client_data)
# Out:
# Trial 1: $391,183.33
# Trial 2: $424,935.00
# Trial 3: $415,800.00
# Trial 4: $420,622.22
# Trial 5: $418,377.27
# Trial 6: $411,931.58
# Trial 7: $399,663.16
# Trial 8: $407,232.00
# Trial 9: $351,577.61
# Trial 10: $413,700.00
#
# Range in prices: $73,357.39

# %% [markdown]
# ### Question 11 - Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %% [markdown]
# #### Answer:
#
# ##### This constructed model can only be used in the real world for estimates
#
# - The data from 1978 has been adjusted to recent using indexes, and it does not reflect current prices.
# - The model is only as good as the training data.
# - The training data comprises of urban setting of Boston housings, hence the model needs training data from a rural setup to forecast that area.
# - Square footage is another important feature which should be taken into consideration to compute $/ft^2 of the neighbourhood houses.
# - The model is giving significantly consistent results, which is a good sign that provided more training data and an extra feature: the model will become comprehensive.
